# %% [markdown]
# # Visualize results after run

# %% [markdown]
# ## 1. Workspace Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorboard as tb
import seaborn as sns
from pathlib import Path

# %%
log_dir = Path("P:\\Projects\\LMB_4Dspine\\Iship_Pau_Altur_Pastor\\4_training_logs\\test\version_19")

# %%
# %load_ext tensorboard
# %tensorboard --logdir log_dir
# Out:
#       <iframe id="tensorboard-frame-38eb7a3a5bf074e0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-38eb7a3a5bf074e0");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
plt.plot(list(range(1, 101)), train_loss['Value'], label='Train Loss')
plt.plot(list(range(1, 101)), val_loss['Value'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.yscale('log')
plt.grid()
plt.legend()
plt.show()

# %%
train_loss
# Out:
#        Wall time  Step     Value
# 0   1.719327e+09     3  0.540663
# 1   1.719327e+09     7  0.389294
# 2   1.719327e+09    11  0.147913
# 3   1.719327e+09    15  0.103304
# 4   1.719327e+09    19  0.105466
# ..           ...   ...       ...
# 95  1.719327e+09   383  0.119834
# 96  1.719327e+09   387  0.090893
# 97  1.719327e+09   391  0.090922
# 98  1.719327e+09   395  0.087462
# 99  1.719327e+09   399  0.087728
#
# [100 rows x 3 columns]
